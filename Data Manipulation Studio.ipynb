# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

data_balt = pd.read_csv("baltimore_9-24-2016_9-30-2017.csv")
data_bost = pd.read_csv("boston_9-24-2016_9-30-2017.csv")
data_ny = pd.read_csv("new-york_9-24-2016_9-30-2017.csv")
data_phil = pd.read_csv("philadelphia_9-24-2016_9-30-2017.csv")

# %%
data_balt.head()
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_bost.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...   Color  Environment  \
# 0    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 1    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 2    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 3    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 4    NaN  09/24/2016        160         180  ...  ORANGE          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_ny.head()
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [5 rows x 25 columns]

# %%
data_phil.head()
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN  NaN       N
# 1          NaN      NaN       NaN         NaN      NaN  NaN       N
# 2          NaN      NaN       NaN         NaN      NaN  NaN       N
# 3          NaN      NaN       NaN         NaN      NaN  NaN       N
# 4          NaN      NaN       NaN         NaN      NaN  NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
for col in data_bost.columns:
    pct_missing = np.mean(data_bost[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
total_cells = np.product(data_bost.shape)

missing_cells = pd.isnull(data_bost).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 47.0 % Missing cells from the data

# %%
data_bost["Type"] = data_bost["Type"].fillna("Conventional")

# %%
data_bost["Color"] = data_bost["Color"].fillna("ORANGE")

# %%
data_bost = data_bost.drop(["Grade","Sub Variety","Origin District","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"],axis=1)

# %%
for col in data_bost.columns:
    pct_missing = np.mean(data_bost[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Item Size - 1%
# Color - 0%
# Repack - 0%

# %%
for col in data_balt.columns:
    pct_missing = np.mean(data_balt[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
data_balt = data_balt.drop(["Grade","Sub Variety","Origin District","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"],axis=1)

# %%
data_balt["Type"] = data_balt["Type"].fillna("Conventional")

# %%
data_balt["Color"] = data_balt["Color"].fillna("ORANGE")

# %%
for col in data_balt.columns:
    pct_missing = np.mean(data_balt[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 1%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Item Size - 16%
# Color - 0%
# Repack - 0%

# %%
total_cells = np.product(data_balt.shape)

missing_cells = pd.isnull(data_balt).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 1.0 % Missing cells from the data

# %%
for col in data_ny.columns:
    pct_missing = np.mean(data_ny[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
data_ny = data_ny.drop(["Grade","Sub Variety","Origin District","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"],axis=1)

# %%
data_ny["Type"] = data_ny["Type"].fillna("Conventional")

# %%
data_ny["Color"] = data_ny["Color"].fillna("ORANGE")

# %%
for col in data_ny.columns:
    pct_missing = np.mean(data_ny[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Item Size - 7%
# Color - 0%
# Repack - 0%

# %%
total_cells = np.product(data_ny.shape)

missing_cells = pd.isnull(data_ny).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 1.0 % Missing cells from the data

# %%
for col in data_phil.columns:
    pct_missing = np.mean(data_phil[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
data_phil = data_phil.drop(["Grade","Sub Variety","Origin District","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"],axis=1)

# %%
data_phil["Type"] = data_phil["Type"].fillna("Conventional")

# %%
data_phil["Color"] = data_phil["Color"].fillna("ORANGE")

# %%
for col in data_phil.columns:
    pct_missing = np.mean(data_phil[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Item Size - 21%
# Color - 0%
# Repack - 0%

# %%
total_cells = np.product(data_phil.shape)

missing_cells = pd.isnull(data_phil).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")
# Out:
# 2.0 % Missing cells from the data

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
data_balt.shape
# Out:
# (153, 14)

# %%
data_bost.shape
# Out:
# (352, 14)

# %%
data_ny.shape
# Out:
# (112, 14)

# %%
data_phil.shape
# Out:
# (57, 14)

# %%
# Combine the four dataframes into one!
northeast_region = pd.concat([data_balt, data_bost, data_ny, data_phil])
northeast_region.head(60)
# Out:
#    Commodity Name  City Name          Type       Package            Variety  \
# 0        PUMPKINS  BALTIMORE  Conventional  24 inch bins                NaN
# 1        PUMPKINS  BALTIMORE  Conventional  24 inch bins                NaN
# 2        PUMPKINS  BALTIMORE  Conventional  24 inch bins        HOWDEN TYPE
# 3        PUMPKINS  BALTIMORE  Conventional  24 inch bins        HOWDEN TYPE
# 4        PUMPKINS  BALTIMORE  Conventional  24 inch bins        HOWDEN TYPE
# 5        PUMPKINS  BALTIMORE  Conventional  24 inch bins        HOWDEN TYPE
# 6        PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 7        PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 8        PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 9        PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 10       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 11       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 12       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 13       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 14       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 15       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 16       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 17       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 18       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 19       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 20       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 21       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 22       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 23       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 24       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 25       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 26       PUMPKINS  BALTIMORE  Conventional  36 inch bins        HOWDEN TYPE
# 27       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN WHITE TYPE
# 28       PUMPKINS  BALTIMORE  Conventional  24 inch bins  HOWDEN WHITE TYPE
# 29       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 30       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 31       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 32       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 33       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 34       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 35       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 36       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 37       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 38       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 39       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 40       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 41       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 42       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 43       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 44       PUMPKINS  BALTIMORE  Conventional  24 inch bins         CINDERELLA
# 45       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 46       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 47       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 48       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 49       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 50       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 51       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 52       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 53       PUMPKINS  BALTIMORE  Conventional   50 lb sacks         CINDERELLA
# 54       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
# 55       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
# 56       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
# 57       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
# 58       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
# 59       PUMPKINS  BALTIMORE  Conventional  24 inch bins          FAIRYTALE
#
#           Date  Low Price  High Price  Mostly Low  Mostly High        Origin  \
# 0   04/29/2017        270       280.0         270        280.0           NaN
# 1   05/06/2017        270       280.0         270        280.0           NaN
# 2   09/24/2016        160       160.0         160        160.0      DELAWARE
# 3   09/24/2016        160       160.0         160        160.0      VIRGINIA
# 4   11/05/2016         90       100.0          90        100.0      MARYLAND
# 5   11/12/2016         90       100.0          90        100.0      MARYLAND
# 6   09/24/2016        160       170.0         160        170.0      MARYLAND
# 7   09/24/2016        160       160.0         160        160.0  PENNSYLVANIA
# 8   10/01/2016        160       170.0         160        170.0      MARYLAND
# 9   10/01/2016        160       160.0         160        160.0  PENNSYLVANIA
# 10  10/08/2016        160       170.0         160        170.0      MARYLAND
# 11  10/08/2016        160       160.0         160        160.0  PENNSYLVANIA
# 12  10/15/2016        150       160.0         150        160.0      MARYLAND
# 13  10/15/2016        150       170.0         150        170.0      MARYLAND
# 14  10/22/2016        150       160.0         150        160.0      MARYLAND
# 15  10/22/2016        140       160.0         140        160.0      MARYLAND
# 16  10/29/2016        100       160.0         100        160.0      MARYLAND
# 17  10/29/2016        130       160.0         130        160.0      MARYLAND
# 18  10/29/2016        130       130.0         130        130.0      MARYLAND
# 19  11/05/2016        120       130.0         120        130.0      MARYLAND
# 20  11/05/2016        100       130.0         100        130.0      MARYLAND
# 21  11/05/2016         90       100.0          90        100.0      MARYLAND
# 22  11/12/2016        100       120.0         100        100.0      MARYLAND
# 23  09/16/2017        160       160.0         160        160.0      MARYLAND
# 24  09/23/2017        160       160.0         160        160.0      MARYLAND
# 25  09/30/2017        150       160.0         150        160.0      MARYLAND
# 26  09/30/2017        150       160.0         150        160.0      MARYLAND
# 27  09/23/2017        160       180.0         160        180.0      MARYLAND
# 28  09/30/2017        180       180.0         180        180.0      MARYLAND
# 29  06/03/2017        380       380.0         380        380.0           NaN
# 30  06/10/2017        380       380.0         380        380.0           NaN
# 31  06/17/2017        380       380.0         380        380.0           NaN
# 32  08/19/2017        200       200.0         200        200.0        MEXICO
# 33  08/26/2017        200       350.0         200        350.0        MEXICO
# 34  09/02/2017        350       350.0         350        350.0        MEXICO
# 35  09/09/2017        180       180.0         180        180.0      MARYLAND
# 36  09/09/2017        200       200.0         200        200.0      VIRGINIA
# 37  09/16/2017        180       200.0         180        200.0      MARYLAND
# 38  09/16/2017        180       200.0         180        200.0      VIRGINIA
# 39  09/23/2017        340       340.0         340        340.0      MARYLAND
# 40  09/23/2017        240       250.0         240        250.0      MARYLAND
# 41  09/23/2017        200       200.0         200        200.0      VIRGINIA
# 42  09/30/2017        340       340.0         340        340.0      MARYLAND
# 43  09/30/2017        240       250.0         240        250.0      MARYLAND
# 44  09/30/2017        180       200.0         180        200.0      VIRGINIA
# 45  08/12/2017         29        29.0          29         29.0    COSTA RICA
# 46  08/12/2017         29        29.0          29         29.0        MEXICO
# 47  08/19/2017         28        29.0          28         29.0    COSTA RICA
# 48  08/26/2017         28        29.0          28         29.0    COSTA RICA
# 49  08/26/2017         29        29.0          29         29.0       FLORIDA
# 50  09/02/2017         29        29.0          29         29.0       FLORIDA
# 51  09/09/2017         15        15.0          15         15.0      VIRGINIA
# 52  09/16/2017         24        24.0          24         24.0        MEXICO
# 53  09/16/2017         15        15.0          15         15.0      VIRGINIA
# 54  09/24/2016        250       260.0         250        260.0      MARYLAND
# 55  09/24/2016        250       260.0         250        260.0      VIRGINIA
# 56  10/01/2016        250       260.0         250        260.0      MARYLAND
# 57  10/01/2016        250       260.0         250        260.0      VIRGINIA
# 58  10/08/2016        235       260.0         235        260.0      MARYLAND
# 59  10/08/2016        250       260.0         250        260.0      VIRGINIA
#
#    Item Size   Color Repack
# 0        lge  ORANGE      E
# 1        lge  ORANGE      E
# 2        med  ORANGE      N
# 3        med  ORANGE      N
# 4        lge  ORANGE      N
# 5        lge  ORANGE      N
# 6        med  ORANGE      N
# 7        lge  ORANGE      N
# 8        med  ORANGE      N
# 9        lge  ORANGE      N
# 10       med  ORANGE      N
# 11       lge  ORANGE      N
# 12       lge  ORANGE      N
# 13       med  ORANGE      N
# 14       lge  ORANGE      N
# 15       med  ORANGE      N
# 16       lge  ORANGE      N
# 17       med  ORANGE      N
# 18       sml  ORANGE      N
# 19      xlge  ORANGE      N
# 20       lge  ORANGE      N
# 21       med  ORANGE      N
# 22       lge  ORANGE      N
# 23   med-lge  ORANGE      N
# 24   med-lge  ORANGE      N
# 25       lge  ORANGE      N
# 26   med-lge  ORANGE      N
# 27       med  ORANGE      N
# 28       med  ORANGE      N
# 29      xlge  ORANGE      E
# 30      xlge  ORANGE      E
# 31      xlge  ORANGE      E
# 32      xlge  ORANGE      N
# 33      xlge  ORANGE      N
# 34      xlge  ORANGE      N
# 35      xlge  ORANGE      N
# 36      xlge  ORANGE      N
# 37      xlge  ORANGE      N
# 38      xlge  ORANGE      N
# 39       jbo  ORANGE      N
# 40      xlge  ORANGE      N
# 41      xlge  ORANGE      N
# 42       jbo  ORANGE      N
# 43      xlge  ORANGE      N
# 44      xlge  ORANGE      N
# 45       lge  ORANGE      N
# 46       lge  ORANGE      N
# 47       lge  ORANGE      N
# 48       lge  ORANGE      N
# 49       med  ORANGE      N
# 50       med  ORANGE      N
# 51       lge  ORANGE      N
# 52       lge  ORANGE      N
# 53       lge  ORANGE      N
# 54      xlge  ORANGE      N
# 55      xlge  ORANGE      N
# 56      xlge  ORANGE      N
# 57      xlge  ORANGE      N
# 58      xlge  ORANGE      N
# 59      xlge  ORANGE      N

# %%
northeast_region.shape
# Out:
# (674, 14)

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
northeast_type_price = northeast_region.groupby('Type')

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
northeast_region_dictionary = {'Low Price':['mean'], "High Price":['mean']}
northeast_price = northeast_type_price.agg(northeast_region_dictionary)
northeast_price
# Out:
#                Low Price  High Price
#                     mean        mean
# Type
# Conventional  134.183976  150.671365

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
